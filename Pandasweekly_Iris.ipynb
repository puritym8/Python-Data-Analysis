# %% [markdown]
# <a href="https://colab.research.google.com/github/puritym8/Python-Data-Analysis/blob/main/Pandasweekly_Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step 2. Import the dataset from this address.

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

# %% [markdown]
# Step 3. Assign it to a variable called iris

# %%
iris = pd.read_csv(url)

iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# Step 4. Create columns for the dataset

# %%
iris.columns = ['sepal_length (in cm)',
                'sepal_width (in cm)',
                'petal_length (in cm)',
                'petal_width (in cm)',
                'class']
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   4.9                  3.0                   1.4
# 1                   4.7                  3.2                   1.3
# 2                   4.6                  3.1                   1.5
# 3                   5.0                  3.6                   1.4
# 4                   5.4                  3.9                   1.7
#
#    petal_width (in cm)        class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.4  Iris-setosa

# %% [markdown]
# Step 5. Is there any missing value in the dataframe?

# %%
iris.isnull().sum()
# Out:
# sepal_length (in cm)    0
# sepal_width (in cm)     0
# petal_length (in cm)    0
# petal_width (in cm)     0
# class                   0
# dtype: int64

# %% [markdown]
# Step 6. Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.loc[10:29, 'petal_length (in cm)'] = np.nan

# %%
iris.head(15)
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                    4.9                  3.0                   1.4
# 1                    4.7                  3.2                   1.3
# 2                    4.6                  3.1                   1.5
# 3                    5.0                  3.6                   1.4
# 4                    5.4                  3.9                   1.7
# 5                    4.6                  3.4                   1.4
# 6                    5.0                  3.4                   1.5
# 7                    4.4                  2.9                   1.4
# 8                    4.9                  3.1                   1.5
# 9                    5.4                  3.7                   1.5
# 10                   4.8                  3.4                   NaN
# 11                   4.8                  3.0                   NaN
# 12                   4.3                  3.0                   NaN
# ...

# %% [markdown]
# Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris['petal_length (in cm)'].fillna(1.0, inplace=True)

# %%
iris.head(15)
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                    4.9                  3.0                   1.4
# 1                    4.7                  3.2                   1.3
# 2                    4.6                  3.1                   1.5
# 3                    5.0                  3.6                   1.4
# 4                    5.4                  3.9                   1.7
# 5                    4.6                  3.4                   1.4
# 6                    5.0                  3.4                   1.5
# 7                    4.4                  2.9                   1.4
# 8                    4.9                  3.1                   1.5
# 9                    5.4                  3.7                   1.5
# 10                   4.8                  3.4                   1.0
# 11                   4.8                  3.0                   1.0
# 12                   4.3                  3.0                   1.0
# ...

# %% [markdown]
# Step 8. Now let's delete the column class

# %%
iris.drop(columns=['class'], inplace=True)

iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   4.9                  3.0                   1.4
# 1                   4.7                  3.2                   1.3
# 2                   4.6                  3.1                   1.5
# 3                   5.0                  3.6                   1.4
# 4                   5.4                  3.9                   1.7
#
#    petal_width (in cm)
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.4

# %% [markdown]
# Step 9. Set the first 3 rows as NaN

# %%
iris.iloc[:3,:] = np.nan

# %%
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   NaN                  NaN                   NaN
# 1                   NaN                  NaN                   NaN
# 2                   NaN                  NaN                   NaN
# 3                   5.0                  3.6                   1.4
# 4                   5.4                  3.9                   1.7
#
#    petal_width (in cm)
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  0.2
# 4                  0.4

# %% [markdown]
# Step 10. Delete the rows that have NaN

# %%
iris.dropna(inplace=True)

iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 3                   5.0                  3.6                   1.4
# 4                   5.4                  3.9                   1.7
# 5                   4.6                  3.4                   1.4
# 6                   5.0                  3.4                   1.5
# 7                   4.4                  2.9                   1.4
#
#    petal_width (in cm)
# 3                  0.2
# 4                  0.4
# 5                  0.3
# 6                  0.2
# 7                  0.2

# %% [markdown]
# Step 11. Reset the index so it begins with 0 again

# %%
iris.reset_index(drop=True, inplace=True)

iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   5.0                  3.6                   1.4
# 1                   5.4                  3.9                   1.7
# 2                   4.6                  3.4                   1.4
# 3                   5.0                  3.4                   1.5
# 4                   4.4                  2.9                   1.4
#
#    petal_width (in cm)
# 0                  0.2
# 1                  0.4
# 2                  0.3
# 3                  0.2
# 4                  0.2

# %% [markdown]
# BONUS: Create your own question and answer it.
# What is the mean sepal length?

# %%
mean_sepal_length = iris['sepal_length (in cm)'].mean()
mean_sepal_length
# Out:
# 5.8712328767123285
