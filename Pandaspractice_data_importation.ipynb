# %% [markdown]
# <a href="https://colab.research.google.com/github/puritym8/Python-Data-Analysis/blob/main/Pandaspractice_data_importation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance

# %%
import yfinance as yf

# %%
#define ticker symbol such as for Apple
ticker_symbol = 'AAPL'

# %%
# define start and end dates

start_date ='2023-01-01'
end_date ='2024-12-31'

# %%
#Fetch the data

data= yf.download(ticker_symbol,start_date,end_date)

data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  130.279999  130.899994  124.169998  125.070000  124.216301
# 2023-01-04  126.889999  128.660004  125.080002  126.360001  125.497498
# 2023-01-05  127.129997  127.769997  124.760002  125.019997  124.166649
# 2023-01-06  126.010002  130.289993  124.889999  129.619995  128.735229
# 2023-01-09  130.470001  133.410004  129.889999  130.149994  129.261612
#
#                Volume
# Date
# 2023-01-03  112117500
# 2023-01-04   89113600
# 2023-01-05   80962700
# 2023-01-06   87754700
# 2023-01-09   70790800
