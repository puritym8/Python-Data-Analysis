# %% [markdown]
# <a href="https://colab.research.google.com/github/puritym8/Python-Data-Analysis/blob/main/Pandasdailypractice4_food.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
#Step 2. Download the dataset to your computer and unzip it.- done

# %%
#Step 3. Use the tsv file and assign it to a dataframe called food

food = pd.read_csv("/content/drive/MyDrive/open food.tsv", delimiter="\t")

food
# Out:
#            code                                                url  \
# 0          3087  http://world-en.openfoodfacts.org/product/0000...
# 1          4530  http://world-en.openfoodfacts.org/product/0000...
# 2          4559  http://world-en.openfoodfacts.org/product/0000...
# 3         16087  http://world-en.openfoodfacts.org/product/0000...
# 4         16094  http://world-en.openfoodfacts.org/product/0000...
# ..          ...                                                ...
# 433   996284712  http://world-en.openfoodfacts.org/product/0000...
# 434  1000004005  http://world-en.openfoodfacts.org/product/0001...
# 435  1000008218  http://world-en.openfoodfacts.org/product/0001...
# 436  1000008706  http://world-en.openfoodfacts.org/product/0001...
# 437         104  http://world-en.openfoodfacts.org/product/0001...
#
#                         creator   created_t      created_datetime  \
# 0    openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# ...

# %%
#Step 4. See the first 5 entries

food.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# 0       1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %%
#Step 5. What is the number of observations in the dataset?

number_of_observations = len(food)

number_of_observations
# Out:
# 438

# %%
#Step 6. What is the number of columns in the dataset?

num_columns = len(food.columns)
num_columns
# Out:
# 163

# %%
food.shape
# Out:
# (438, 163)

# %%
#Step 7. Print the name of all the columns.

list(food.columns)
# Out:
# ['code',
#  'url',
#  'creator',
#  'created_t',
#  'created_datetime',
#  'last_modified_t',
#  'last_modified_datetime',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_en',
#  'origins',
#  'origins_tags',
#  'manufacturing_places',
#  'manufacturing_places_tags',
#  'labels',
#  'labels_tags',
#  'labels_en',
#  'emb_codes',
#  'emb_codes_tags',
#  'first_packaging_code_geo',
#  'cities',
#  'cities_tags',
#  'purchase_places',
#  'stores',
#  'countries',
#  'countries_tags',
#  'countries_en',
#  'ingredients_text',
#  'allergens',
#  'allergens_en',
#  'traces',
#  'traces_tags',
#  'traces_en',
#  'serving_size',
#  'no_nutriments',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'additives_en',
#  'ingredients_from_palm_oil_n',
#  'ingredients_from_palm_oil',
#  'ingredients_from_palm_oil_tags',
# ...

# %%
#Step 8. What is the name of 105th column?

column_105_name = food.columns[104]

column_105_name
# Out:
# '-glucose_100g'

# %%
#Step 9. What is the type of the observations of the 105th column?

column_105_type = food.dtypes[104]

column_105_type
# Out:
# dtype('float64')

# %%
#Step 10. How is the dataset indexed?

food.index
# Out:
# RangeIndex(start=0, stop=438, step=1)

# %%
#Step 11. What is the product name of the 19th observation?

product_name_19th_observation = food.loc[18,'product_name']

product_name_19th_observation
# Out:
# 'Lotus Organic Brown Jasmine Rice'
